# %% [markdown]
# # Stock Market Prediction using Numerical and Textual Analysis
#
# ● Objective: Created a hybrid model for stock price/performance prediction using numerical analysis of historical stock prices, and sentimental analysis of news headlines <br>
# ● Stock to analyze and predict - GC=F <br>
# ● Downloaded the historical stock prices from finance.yahoo.com <br>
# ● Downloaded the textual (news) data from https://bit.ly/36fFPI6 <br>
# ● Used Python for separate analysis and then combine the findings to create a hybrid model<br>

# %% [markdown]
# # Importing Necessary Libraries and Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock_price = pd.read_csv('GC=F.csv')
stock_headlines = pd.read_csv('india-news-headlines.csv')

# %%
stock_price.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2000-09-01  277.000000  277.000000  277.000000  277.000000  277.000000
# 1  2000-09-04         NaN         NaN         NaN         NaN         NaN
# 2  2000-09-05  275.799988  275.799988  275.799988  275.799988  275.799988
# 3  2000-09-06  274.200012  274.200012  274.200012  274.200012  274.200012
# 4  2000-09-07  274.000000  274.000000  274.000000  274.000000  274.000000
#
#    Volume
# 0     0.0
# 1     NaN
# 2     2.0
# 3     0.0
# 4   125.0

# %%
stock_price.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5174.000000  5174.000000  5174.000000  5174.000000  5174.000000
# mean   1014.490414  1019.622227  1008.955431  1014.360398  1014.360398
# std     487.891475   490.860400   484.551170   487.770323   487.770323
# min     255.000000   256.100006   255.000000   255.100006   255.100006
# 25%     474.899994   477.349991   473.374992   474.800010   474.800010
# 50%    1171.049988  1176.400024  1164.600036  1170.300049  1170.300049
# 75%    1331.775024  1338.924988  1325.275024  1331.574982  1331.574982
# max    2045.500000  2063.000000  2040.000000  2051.500000  2051.500000
#
#               Volume
# count    5174.000000
# mean     4281.436413
# std     24607.742016
# min         0.000000
# 25%        17.000000
# 50%        94.000000
# 75%       358.000000
# max    386334.000000

# %%
stock_price.shape
# Out:
# (5286, 7)

# %%
stock_headlines.head()
# Out:
#    publish_date headline_category  \
# 0      20010102           unknown
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
stock_headlines.shape
# Out:
# (3424067, 3)

# %%
print(stock_headlines['publish_date'].dtype)
print(stock_price['Date'].dtype) #needs to be converted to datetime
# Out:
# int64
# object

# %%
sns.heatmap(stock_price.isnull(),yticklabels=False,cmap='viridis',cbar=False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(stock_headlines.isnull(),yticklabels=False,cmap='viridis',cbar=False)
# Out:
# <AxesSubplot:>

# %%
#dropping null and duplicate entries in our data
stock_price.dropna(inplace = True)
stock_price = stock_price.drop_duplicates()
stock_headlines.dropna(inplace = True)
stock_headlines = stock_headlines.drop_duplicates()

# %%
len(stock_price), len(stock_headlines)
# Out:
# (5174, 3399876)

# %%
sns.heatmap(stock_price.isnull(),yticklabels=False,cmap='viridis',cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # STOCK PRICE

# %%
# coverting the datatype of column 'Date' from type object to type 'datetime'
stock_price['Date'] = pd.to_datetime(stock_price['Date']).dt.normalize()

# filtering the important columns
stock_price = stock_price.filter(['Date', 'Close', 'Open', 'High', 'Low', 'Volume'])

#setting column 'Date' as the index column
stock_price.set_index('Date', inplace= True)

# sorting the data according to Date
stock_price = stock_price.sort_index(ascending=True, axis=0)
stock_price
# Out:
#                   Close         Open         High          Low  Volume
# Date
# 2000-09-01   277.000000   277.000000   277.000000   277.000000     0.0
# 2000-09-05   275.799988   275.799988   275.799988   275.799988     2.0
# 2000-09-06   274.200012   274.200012   274.200012   274.200012     0.0
# 2000-09-07   274.000000   274.000000   274.000000   274.000000   125.0
# 2000-09-08   273.299988   273.299988   273.299988   273.299988     0.0
# ...                 ...          ...          ...          ...     ...
# 2021-05-28  1902.500000  1897.500000  1905.400024  1881.900024  2415.0
# 2021-06-01  1902.900024  1905.099976  1916.199951  1892.800049   640.0
# 2021-06-02  1907.500000  1899.199951  1908.800049  1896.000000  1267.0
# 2021-06-03  1871.199951  1908.800049  1908.800049  1865.000000  1021.0
# 2021-06-04  1889.800049  1869.300049  1895.500000  1854.000000  1021.0
#
# [5174 rows x 5 columns]

# %% [markdown]
# # STOCK HEADLINES

# %%
# coverting the datatype of column 'Date' from type string to type 'datetime'
stock_headlines['publish_date'] = stock_headlines['publish_date'].astype(str)
stock_headlines['publish_date'] = stock_headlines['publish_date'].apply(lambda x: x[0:4]+'-'+x[4:6]+'-'+x[6:8])
stock_headlines['publish_date'] = pd.to_datetime(stock_headlines['publish_date']).dt.normalize()

# filtering the important columns 
stock_headlines = stock_headlines.filter(['publish_date', 'headline_text'])

# grouping the news headlines according to Date
stock_headlines = stock_headlines.groupby(['publish_date'])['headline_text'].apply(lambda x: ','.join(x)).reset_index()

# setting Date as the index column
stock_headlines.set_index('publish_date', inplace= True)

# sorting the data according to the Date
stock_headlines = stock_headlines.sort_index(ascending=True, axis=0)
stock_headlines
# Out:
#                                                   headline_text
# publish_date
# 2001-01-02    Status quo will not be disturbed at Ayodhya; s...
# 2001-01-03    Powerless north India gropes in the dark,Think...
# 2001-01-04    The string that pulled Stephen Hawking to Indi...
# 2001-01-05    Light combat craft takes India into club class...
# 2001-01-06    Light combat craft takes India into club class...
# ...                                                         ...
# 2020-12-27    #BigInterview! Dhritiman Chatterjee: Nobody da...
# 2020-12-28    Horoscope Today; 28 December 2020: Check astro...
# 2020-12-29    Man recovers charred remains of 'thief' from h...
# 2020-12-30    Numerology Readings 30 December 2020: Predicti...
# 2020-12-31    Horoscope Today; 31 December 2020: Check astro...
#
# [7262 rows x 1 columns]

# %%
from textblob import TextBlob
polarity = []
subjectivity = []
for idx, row in stock_headlines.iterrows():
  polarity.append(TextBlob(row['headline_text']).sentiment[0])
  subjectivity.append(TextBlob(row['headline_text']).sentiment[1])

# %%
stock_headlines['polarity'] = polarity
stock_headlines['subjectivity'] = subjectivity
stock_headlines
# Out:
#                                                   headline_text  polarity  \
# publish_date
# 2001-01-02    Status quo will not be disturbed at Ayodhya; s...  0.148485
# 2001-01-03    Powerless north India gropes in the dark,Think...  0.108333
# 2001-01-04    The string that pulled Stephen Hawking to Indi...  0.115404
# 2001-01-05    Light combat craft takes India into club class...  0.257045
# 2001-01-06    Light combat craft takes India into club class...  0.219481
# ...                                                         ...       ...
# 2020-12-27    #BigInterview! Dhritiman Chatterjee: Nobody da...  0.044470
# 2020-12-28    Horoscope Today; 28 December 2020: Check astro...  0.081137
# 2020-12-29    Man recovers charred remains of 'thief' from h...  0.066816
# 2020-12-30    Numerology Readings 30 December 2020: Predicti...  0.058847
# 2020-12-31    Horoscope Today; 31 December 2020: Check astro...  0.100443
#
#               subjectivity
# publish_date
# 2001-01-02        0.240909
# 2001-01-03        0.458333
# 2001-01-04        0.512342
# 2001-01-05        0.462652
# 2001-01-06        0.464935
# ...                    ...
# 2020-12-27        0.407395
# 2020-12-28        0.417158
# 2020-12-29        0.412775
# 2020-12-30        0.433598
# 2020-12-31        0.392380
#
# [7262 rows x 3 columns]

# %%
stock_price
# Out:
#                   Close         Open         High          Low  Volume
# Date
# 2000-09-01   277.000000   277.000000   277.000000   277.000000     0.0
# 2000-09-05   275.799988   275.799988   275.799988   275.799988     2.0
# 2000-09-06   274.200012   274.200012   274.200012   274.200012     0.0
# 2000-09-07   274.000000   274.000000   274.000000   274.000000   125.0
# 2000-09-08   273.299988   273.299988   273.299988   273.299988     0.0
# ...                 ...          ...          ...          ...     ...
# 2021-05-28  1902.500000  1897.500000  1905.400024  1881.900024  2415.0
# 2021-06-01  1902.900024  1905.099976  1916.199951  1892.800049   640.0
# 2021-06-02  1907.500000  1899.199951  1908.800049  1896.000000  1267.0
# 2021-06-03  1871.199951  1908.800049  1908.800049  1865.000000  1021.0
# 2021-06-04  1889.800049  1869.300049  1895.500000  1854.000000  1021.0
#
# [5174 rows x 5 columns]

# %%
# concatenation of the datasets stock_price and stock_headlines
stock_data = pd.concat([stock_price, stock_headlines], axis=1)
stock_data.dropna(axis=0, inplace=True)

# displaying the combined stock_data
stock_data
# Out:
#                   Close         Open         High          Low  Volume  \
# 2001-01-02   268.399994   268.399994   268.399994   268.399994     0.0
# 2001-01-03   268.000000   268.000000   268.000000   268.000000     1.0
# 2001-01-04   267.299988   267.299988   267.299988   267.299988     1.0
# 2001-01-05   268.000000   268.000000   268.000000   268.000000     0.0
# 2001-01-08   268.000000   268.000000   268.000000   268.000000     0.0
# ...                 ...          ...          ...          ...     ...
# 2020-12-23  1874.699951  1867.000000  1878.800049  1864.500000    82.0
# 2020-12-28  1877.199951  1895.500000  1895.800049  1873.699951    75.0
# 2020-12-29  1879.699951  1881.300049  1881.300049  1879.699951   343.0
# 2020-12-30  1891.000000  1879.900024  1895.800049  1877.300049   444.0
# 2020-12-31  1893.099976  1897.000000  1901.300049  1892.699951   127.0
#
#                                                 headline_text  polarity  \
# 2001-01-02  Status quo will not be disturbed at Ayodhya; s...  0.148485
# 2001-01-03  Powerless north India gropes in the dark,Think...  0.108333
# 2001-01-04  The string that pulled Stephen Hawking to Indi...  0.115404
# 2001-01-05  Light combat craft takes India into club class...  0.257045
# 2001-01-08  Sangh Parivar; Babri panel up the ante,Frontru...  0.013447
# ...                                                       ...       ...
# 2020-12-23  Sawmill in Makarpura GIDC gutted; none hurt,Ci...  0.081997
# 2020-12-28  Horoscope Today; 28 December 2020: Check astro...  0.081137
# 2020-12-29  Man recovers charred remains of 'thief' from h...  0.066816
# 2020-12-30  Numerology Readings 30 December 2020: Predicti...  0.058847
# 2020-12-31  Horoscope Today; 31 December 2020: Check astro...  0.100443
#
#             subjectivity
# 2001-01-02      0.240909
# 2001-01-03      0.458333
# 2001-01-04      0.512342
# 2001-01-05      0.462652
# 2001-01-08      0.316351
# ...                  ...
# 2020-12-23      0.392756
# 2020-12-28      0.417158
# 2020-12-29      0.412775
# 2020-12-30      0.433598
# 2020-12-31      0.392380
#
# [4958 rows x 8 columns]

# %% [markdown]
# # Stock Data Analysis

# %%
plt.figure(figsize=(15,10))
stock_data['Close'].plot()

plt.title("Close Price")
plt.xlabel('Date')
plt.ylabel('Close Price (INR)')
# Out:
# Text(0, 0.5, 'Close Price (INR)')

# %%
# calculating 7 day rolling mean
stock_data.rolling(7).mean().head(20)
# Out:
#                  Close        Open        High         Low       Volume  \
# 2001-01-02         NaN         NaN         NaN         NaN          NaN
# 2001-01-03         NaN         NaN         NaN         NaN          NaN
# 2001-01-04         NaN         NaN         NaN         NaN          NaN
# 2001-01-05         NaN         NaN         NaN         NaN          NaN
# 2001-01-08         NaN         NaN         NaN         NaN          NaN
# 2001-01-09         NaN         NaN         NaN         NaN          NaN
# 2001-01-10  267.414285  267.414285  267.414285  267.414285     0.285714
# 2001-01-23  267.085715  267.085715  267.085715  267.085715     0.285714
# 2001-01-24  266.557142  266.557142  266.557142  266.557142     0.142857
# 2001-01-25  266.157144  266.157144  266.157144  266.157144     0.000000
# 2001-01-26  265.414285  265.414285  265.414285  265.414285     0.000000
# 2001-01-29  264.671426  264.671426  264.671426  264.671426  2212.714286
# 2001-01-30  264.385712  264.014282  264.542855  264.014282  2463.285714
# 2001-01-31  264.514282  264.085711  264.728568  263.871425  2544.142857
# 2001-02-01  264.857139  264.114280  265.128566  263.899994  2602.714286
# 2001-02-02  265.257141  264.642853  265.685713  264.214281  2618.000000
# 2001-02-05  265.357143  264.728568  265.871425  264.299997  2645.428571
# 2001-02-06  265.428571  264.885712  266.028569  264.157139  2649.000000
# 2001-02-07  265.428571  264.885712  266.128571  264.099997   460.000000
# 2001-02-08  264.657144  264.971427  265.685713  263.657139   211.285714
#
#             polarity  subjectivity
# 2001-01-02       NaN           NaN
# 2001-01-03       NaN           NaN
# 2001-01-04       NaN           NaN
# 2001-01-05       NaN           NaN
# 2001-01-08       NaN           NaN
# 2001-01-09       NaN           NaN
# 2001-01-10  0.089065      0.359502
# 2001-01-23  0.076533      0.371638
# 2001-01-24  0.075342      0.341082
# 2001-01-25  0.067394      0.330374
# 2001-01-26  0.050425      0.298967
# 2001-01-29  0.079347      0.291979
# 2001-01-30  0.100464      0.274337
# 2001-01-31  0.108627      0.320595
# 2001-02-01  0.117188      0.324278
# 2001-02-02  0.125670      0.324625
# 2001-02-05  0.110053      0.311977
# 2001-02-06  0.088786      0.308749
# 2001-02-07  0.075800      0.307846
# 2001-02-08  0.086331      0.305753

# %%
# setting figure size
plt.figure(figsize=(15,10))

# plotting the close price and a 30-day rolling mean of close price
stock_data['Close'].plot()
stock_data.rolling(window=30).mean()['Close'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Predicting opening price

# %%
#predicting opening prices
df= stock_data[['Open', 'High',  'Volume', 'polarity', 'subjectivity']]
y=df['High']
X=df.copy()
X.drop('High',axis=1,inplace=True)

# %%
#importing test train split
from sklearn.model_selection import train_test_split

#Train-Test split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.15,shuffle=False)
X_test
# Out:
#                    Open  Volume  polarity  subjectivity
# 2018-01-05  1320.300049     1.0  0.063854      0.374854
# 2018-01-08  1319.900024    41.0  0.087401      0.388622
# 2018-01-09  1309.599976    16.0  0.067696      0.390484
# 2018-01-10  1320.300049    70.0  0.052244      0.387770
# 2018-01-11  1317.099976     9.0  0.046267      0.341841
# ...                 ...     ...       ...           ...
# 2020-12-23  1867.000000    82.0  0.081997      0.392756
# 2020-12-28  1895.500000    75.0  0.081137      0.417158
# 2020-12-29  1881.300049   343.0  0.066816      0.412775
# 2020-12-30  1879.900024   444.0  0.058847      0.433598
# 2020-12-31  1897.000000   127.0  0.100443      0.392380
#
# [744 rows x 4 columns]

# %%
#LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
LinearRegression_model= LinearRegression()
LinearRegression_model.fit(X_train,y_train)
acc_LinearRegression =LinearRegression_model.score(X_test,y_test)
acc_LinearRegression
# Out:
# 0.9983553437652833

# %%
#DECISION TREE REGRESSION
from sklearn.tree import DecisionTreeRegressor
DecisionTree_model= DecisionTreeRegressor()
DecisionTree_model.fit(X_train,y_train)
acc_DecisionTree =DecisionTree_model.score(X_test,y_test)
acc_DecisionTree
# Out:
# 0.9889154835480183

# %%
#KNN NEIGHBORS
from sklearn import neighbors
knn_model=neighbors.KNeighborsRegressor(n_neighbors=4)
knn_model.fit(X_train,y_train)
acc_knn =knn_model.score(X_test,y_test)
acc_knn
# Out:
# 0.7813515417593736

# %%
from xgboost import XGBRegressor 
from sklearn.metrics import mean_squared_error
xgb = XGBRegressor(n_estimators = 20000, n_jobs = -1, learning_rate = 0.15, random_state = 0, max_depth = 8, reg_lambda = 0.5)
xgb.fit(X_train, y_train, early_stopping_rounds = 200, eval_set = [(X_test,y_test)], eval_metric = 'rmse', verbose = True)
cv_pred = xgb.predict(X_test)
print(np.sqrt(mean_squared_error(y_test, cv_pred)))
print(xgb.score(X_test,y_test))
# Out:
# [0]	validation_0-rmse:1285.13550
# [1]	validation_0-rmse:1095.56055
# [2]	validation_0-rmse:935.90936
# [3]	validation_0-rmse:800.98852
# [4]	validation_0-rmse:685.04889
# [5]	validation_0-rmse:586.12054
# [6]	validation_0-rmse:502.54791
# [7]	validation_0-rmse:431.90851
# [8]	validation_0-rmse:371.16623
# [9]	validation_0-rmse:320.12527
# [10]	validation_0-rmse:274.69745
# [11]	validation_0-rmse:236.56808
# [12]	validation_0-rmse:205.04962
# [13]	validation_0-rmse:176.93034
# [14]	validation_0-rmse:152.90927
# [15]	validation_0-rmse:132.49722
# [16]	validation_0-rmse:115.82613
# [17]	validation_0-rmse:101.32471
# [18]	validation_0-rmse:88.88540
# [19]	validation_0-rmse:78.45951
# [20]	validation_0-rmse:69.12485
# [21]	validation_0-rmse:61.64856
# [22]	validation_0-rmse:54.97842
# [23]	validation_0-rmse:49.35039
# [24]	validation_0-rmse:44.66184
# [25]	validation_0-rmse:40.75611
# [26]	validation_0-rmse:37.27529
# [27]	validation_0-rmse:34.96839
# [28]	validation_0-rmse:32.85760
# [29]	validation_0-rmse:31.34543
# [30]	validation_0-rmse:30.02974
# [31]	validation_0-rmse:29.03780
# [32]	validation_0-rmse:27.79001
# [33]	validation_0-rmse:27.05577
# [34]	validation_0-rmse:26.45477
# [35]	validation_0-rmse:26.09811
# [36]	validation_0-rmse:25.82990
# [37]	validation_0-rmse:25.50822
# [38]	validation_0-rmse:25.30007
# [39]	validation_0-rmse:25.08207
# [40]	validation_0-rmse:24.84434
# [41]	validation_0-rmse:24.71372
# [42]	validation_0-rmse:24.64690
# [43]	validation_0-rmse:24.52147
# [44]	validation_0-rmse:24.43887
# [45]	validation_0-rmse:24.38289
# [46]	validation_0-rmse:24.30042
# [47]	validation_0-rmse:24.25591
# [48]	validation_0-rmse:24.23675
# [49]	validation_0-rmse:24.21588
# [50]	validation_0-rmse:24.20226
# [51]	validation_0-rmse:24.18212
# [52]	validation_0-rmse:24.16968
# [53]	validation_0-rmse:24.17586
# [54]	validation_0-rmse:24.13014
# [55]	validation_0-rmse:24.12818
# [56]	validation_0-rmse:24.11729
# [57]	validation_0-rmse:24.08701
# [58]	validation_0-rmse:24.08330
# [59]	validation_0-rmse:24.06193
# [60]	validation_0-rmse:24.05912
# [61]	validation_0-rmse:23.95965
# [62]	validation_0-rmse:23.96149
# [63]	validation_0-rmse:23.94986
# [64]	validation_0-rmse:23.94061
# [65]	validation_0-rmse:23.82063
# [66]	validation_0-rmse:23.71480
# [67]	validation_0-rmse:23.71521
# [68]	validation_0-rmse:23.71558
# [69]	validation_0-rmse:23.62209
# [70]	validation_0-rmse:23.61638
# [71]	validation_0-rmse:23.61872
# [72]	validation_0-rmse:23.59881
# [73]	validation_0-rmse:23.59766
# [74]	validation_0-rmse:23.56904
# [75]	validation_0-rmse:23.56810
# [76]	validation_0-rmse:23.57529
# [77]	validation_0-rmse:23.49382
# [78]	validation_0-rmse:23.49580
# [79]	validation_0-rmse:23.50194
# [80]	validation_0-rmse:23.50115
# [81]	validation_0-rmse:23.50118
# [82]	validation_0-rmse:23.42475
# [83]	validation_0-rmse:23.42466
# [84]	validation_0-rmse:23.43119
# [85]	validation_0-rmse:23.43203
# [86]	validation_0-rmse:23.44547
# [87]	validation_0-rmse:23.45456
# [88]	validation_0-rmse:23.45406
# [89]	validation_0-rmse:23.45569
# [90]	validation_0-rmse:23.45167
# [91]	validation_0-rmse:23.46034
# [92]	validation_0-rmse:23.45933
# [93]	validation_0-rmse:23.45895
# [94]	validation_0-rmse:23.46267
# [95]	validation_0-rmse:23.46202
# [96]	validation_0-rmse:23.46548
# [97]	validation_0-rmse:23.46564
# [98]	validation_0-rmse:23.47325
# [99]	validation_0-rmse:23.47316
# [100]	validation_0-rmse:23.47404
# [101]	validation_0-rmse:23.47691
# [102]	validation_0-rmse:23.47237
# [103]	validation_0-rmse:23.47287
# [104]	validation_0-rmse:23.46701
# [105]	validation_0-rmse:23.46732
# [106]	validation_0-rmse:23.46981
# [107]	validation_0-rmse:23.46759
# [108]	validation_0-rmse:23.46530
# [109]	validation_0-rmse:23.47674
# [110]	validation_0-rmse:23.47770
# [111]	validation_0-rmse:23.47754
# [112]	validation_0-rmse:23.47759
# [113]	validation_0-rmse:23.48210
# [114]	validation_0-rmse:23.47023
# [115]	validation_0-rmse:23.47079
# [116]	validation_0-rmse:23.46786
# [117]	validation_0-rmse:23.47158
# [118]	validation_0-rmse:23.47474
# [119]	validation_0-rmse:23.46428
# [120]	validation_0-rmse:23.46374
# [121]	validation_0-rmse:23.47542
# [122]	validation_0-rmse:23.47727
# [123]	validation_0-rmse:23.48291
# [124]	validation_0-rmse:23.46960
# [125]	validation_0-rmse:23.46954
# [126]	validation_0-rmse:23.46944
# [127]	validation_0-rmse:23.46970
# [128]	validation_0-rmse:23.47806
# [129]	validation_0-rmse:23.48007
# [130]	validation_0-rmse:23.47973
# [131]	validation_0-rmse:23.48329
# [132]	validation_0-rmse:23.48242
# [133]	validation_0-rmse:23.48697
# [134]	validation_0-rmse:23.48794
# [135]	validation_0-rmse:23.48625
# [136]	validation_0-rmse:23.48672
# [137]	validation_0-rmse:23.49072
# [138]	validation_0-rmse:23.49045
# [139]	validation_0-rmse:23.49955
# [140]	validation_0-rmse:23.49876
# [141]	validation_0-rmse:23.49553
# [142]	validation_0-rmse:23.49403
# [143]	validation_0-rmse:23.49321
# [144]	validation_0-rmse:23.49223
# [145]	validation_0-rmse:23.49331
# [146]	validation_0-rmse:23.49665
# [147]	validation_0-rmse:23.49885
# [148]	validation_0-rmse:23.50513
# [149]	validation_0-rmse:23.50466
# [150]	validation_0-rmse:23.50218
# [151]	validation_0-rmse:23.50257
# [152]	validation_0-rmse:23.50236
# [153]	validation_0-rmse:23.50252
# [154]	validation_0-rmse:23.50409
# [155]	validation_0-rmse:23.50538
# [156]	validation_0-rmse:23.50511
# [157]	validation_0-rmse:23.49379
# [158]	validation_0-rmse:23.49643
# [159]	validation_0-rmse:23.48821
# [160]	validation_0-rmse:23.48838
# [161]	validation_0-rmse:23.48814
# [162]	validation_0-rmse:23.48769
# [163]	validation_0-rmse:23.48638
# [164]	validation_0-rmse:23.48571
# [165]	validation_0-rmse:23.48636
# [166]	validation_0-rmse:23.48665
# [167]	validation_0-rmse:23.48657
# [168]	validation_0-rmse:23.48758
# [169]	validation_0-rmse:23.48824
# [170]	validation_0-rmse:23.49222
# [171]	validation_0-rmse:23.49063
# [172]	validation_0-rmse:23.48783
# [173]	validation_0-rmse:23.48757
# [174]	validation_0-rmse:23.48671
# [175]	validation_0-rmse:23.48724
# [176]	validation_0-rmse:23.48611
# [177]	validation_0-rmse:23.48283
# [178]	validation_0-rmse:23.48272
# [179]	validation_0-rmse:23.48188
# [180]	validation_0-rmse:23.48097
# [181]	validation_0-rmse:23.48193
# [182]	validation_0-rmse:23.48200
# [183]	validation_0-rmse:23.48338
# [184]	validation_0-rmse:23.48687
# [185]	validation_0-rmse:23.48727
# [186]	validation_0-rmse:23.48794
# [187]	validation_0-rmse:23.48792
# [188]	validation_0-rmse:23.48790
# [189]	validation_0-rmse:23.48369
# [190]	validation_0-rmse:23.48446
# [191]	validation_0-rmse:23.48896
# [192]	validation_0-rmse:23.48918
# [193]	validation_0-rmse:23.48880
# [194]	validation_0-rmse:23.48669
# [195]	validation_0-rmse:23.48673
# [196]	validation_0-rmse:23.48142
# [197]	validation_0-rmse:23.48156
# [198]	validation_0-rmse:23.48855
# [199]	validation_0-rmse:23.48678
# [200]	validation_0-rmse:23.48792
# [201]	validation_0-rmse:23.48601
# [202]	validation_0-rmse:23.48665
# [203]	validation_0-rmse:23.48656
# [204]	validation_0-rmse:23.48616
# [205]	validation_0-rmse:23.48414
# [206]	validation_0-rmse:23.48314
# [207]	validation_0-rmse:23.48501
# [208]	validation_0-rmse:23.48528
# [209]	validation_0-rmse:23.48575
# [210]	validation_0-rmse:23.48688
# [211]	validation_0-rmse:23.48644
# [212]	validation_0-rmse:23.48664
# [213]	validation_0-rmse:23.48847
# [214]	validation_0-rmse:23.48778
# [215]	validation_0-rmse:23.48890
# [216]	validation_0-rmse:23.48491
# [217]	validation_0-rmse:23.48447
# [218]	validation_0-rmse:23.48429
# [219]	validation_0-rmse:23.47882
# [220]	validation_0-rmse:23.47959
# [221]	validation_0-rmse:23.48338
# [222]	validation_0-rmse:23.48045
# [223]	validation_0-rmse:23.48058
# [224]	validation_0-rmse:23.47921
# [225]	validation_0-rmse:23.47963
# [226]	validation_0-rmse:23.47974
# [227]	validation_0-rmse:23.47224
# [228]	validation_0-rmse:23.47245
# [229]	validation_0-rmse:23.47287
# [230]	validation_0-rmse:23.47474
# [231]	validation_0-rmse:23.47490
# [232]	validation_0-rmse:23.47496
# [233]	validation_0-rmse:23.47343
# [234]	validation_0-rmse:23.47222
# [235]	validation_0-rmse:23.47201
# [236]	validation_0-rmse:23.47231
# [237]	validation_0-rmse:23.47091
# [238]	validation_0-rmse:23.47370
# [239]	validation_0-rmse:23.47356
# [240]	validation_0-rmse:23.47351
# [241]	validation_0-rmse:23.47231
# [242]	validation_0-rmse:23.47218
# [243]	validation_0-rmse:23.47037
# [244]	validation_0-rmse:23.47057
# [245]	validation_0-rmse:23.47072
# [246]	validation_0-rmse:23.47063
# [247]	validation_0-rmse:23.47201
# [248]	validation_0-rmse:23.47153
# [249]	validation_0-rmse:23.46945
# [250]	validation_0-rmse:23.47026
# [251]	validation_0-rmse:23.47081
# [252]	validation_0-rmse:23.47053
# [253]	validation_0-rmse:23.47042
# [254]	validation_0-rmse:23.47118
# [255]	validation_0-rmse:23.47120
# [256]	validation_0-rmse:23.47317
# [257]	validation_0-rmse:23.46852
# [258]	validation_0-rmse:23.46739
# [259]	validation_0-rmse:23.46609
# [260]	validation_0-rmse:23.46655
# [261]	validation_0-rmse:23.46946
# [262]	validation_0-rmse:23.46985
# [263]	validation_0-rmse:23.46985
# [264]	validation_0-rmse:23.47006
# [265]	validation_0-rmse:23.47003
# [266]	validation_0-rmse:23.46995
# [267]	validation_0-rmse:23.47052
# [268]	validation_0-rmse:23.46963
# [269]	validation_0-rmse:23.47004
# [270]	validation_0-rmse:23.46826
# [271]	validation_0-rmse:23.46821
# [272]	validation_0-rmse:23.46868
# [273]	validation_0-rmse:23.46897
# [274]	validation_0-rmse:23.46930
# [275]	validation_0-rmse:23.46923
# [276]	validation_0-rmse:23.47116
# [277]	validation_0-rmse:23.47114
# [278]	validation_0-rmse:23.47062
# [279]	validation_0-rmse:23.47082
# [280]	validation_0-rmse:23.46701
# [281]	validation_0-rmse:23.46701
# [282]	validation_0-rmse:23.47228
# [283]	validation_0-rmse:23.47296
# 23.42465690922762
# 0.9906018966409996

# %%
y_predict=LinearRegression_model.predict(X_test)
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from math import sqrt

k=X_test.shape[1]
n=len(X_test)
RMSE= float(format(np.sqrt(mean_squared_error(y_test,y_predict)),'.3f'))
MSE= mean_squared_error(y_test,y_predict)
MAE= mean_absolute_error(y_test,y_predict)
r2=r2_score(y_test,y_predict)
adj_r2= 1-(1-r2)*(n-1)/(n-k-1)

print("RMSE= ",RMSE)
print("MSE= ",MSE)
print("MAE= ",MAE)
print("R2= ",r2)
print("Adjusted R2= ",adj_r2)
# Out:
# RMSE=  9.799
# MSE=  96.02435442846323
# MAE=  6.918894974201764
# R2=  0.9983553437652833
# Adjusted R2=  0.9983464417017666

# %%
b=y_test.to_frame()
a = pd.DataFrame(y_predict,columns=["Predicted value"],index=b.index)
result = pd.concat([b, a], axis=1)
result
# Out:
#                    High  Predicted value
# 2018-01-05  1320.300049      1327.595131
# 2018-01-08  1319.900024      1327.191786
# 2018-01-09  1311.699951      1316.851549
# 2018-01-10  1320.699951      1327.627438
# 2018-01-11  1320.599976      1324.335999
# ...                 ...              ...
# 2020-12-23  1878.800049      1877.687178
# 2020-12-28  1895.800049      1906.406398
# 2020-12-29  1881.300049      1892.119507
# 2020-12-30  1895.800049      1890.752355
# 2020-12-31  1901.300049      1907.852582
#
# [744 rows x 2 columns]

# %%
# plotting
plt.figure(figsize=(16,10))
plt.plot(a, label="Predicted Opening Price")
plt.plot(b, label="Testing Opening Price")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=2)
plt.show()

# %% [markdown]
# # Predicting closing prices

# %%
df1= stock_data[['Open', 'Low',  'Volume', 'polarity', 'subjectivity']]
y=df1['Low']
X=df1.copy()
X.drop('Low',axis=1,inplace=True)

# %%
#importing test train split
from sklearn.model_selection import train_test_split

#Train-Test split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.15,shuffle=False)
y_test
# Out:
# 2018-01-05    1320.300049
# 2018-01-08    1314.599976
# 2018-01-09    1309.599976
# 2018-01-10    1315.300049
# 2018-01-11    1316.300049
#                  ...
# 2020-12-23    1864.500000
# 2020-12-28    1873.699951
# 2020-12-29    1879.699951
# 2020-12-30    1877.300049
# 2020-12-31    1892.699951
# Name: Low, Length: 744, dtype: float64

# %%
#LINEAR REGRESSION
from sklearn.linear_model import LinearRegression
LinearRegression_model= LinearRegression()
LinearRegression_model.fit(X_train,y_train)
acc_LinearRegression =LinearRegression_model.score(X_test,y_test)
acc_LinearRegression
# Out:
# 0.9975152194359665

# %%
#DECISION TREE REGRESSION
from sklearn.tree import DecisionTreeRegressor
DecisionTree_model= DecisionTreeRegressor()
DecisionTree_model.fit(X_train,y_train)
acc_DecisionTree =DecisionTree_model.score(X_test,y_test)
acc_DecisionTree
# Out:
# 0.9724135120962761

# %%
#KNN NEIGHBORS
from sklearn import neighbors
knn_model=neighbors.KNeighborsRegressor(n_neighbors=1)
knn_model.fit(X_train,y_train)
acc_knn =knn_model.score(X_test,y_test)
acc_knn
# Out:
# 0.761858253980733

# %%
from xgboost import XGBRegressor 
from sklearn.metrics import mean_squared_error
xgb = XGBRegressor(n_estimators = 20000, n_jobs = -1, learning_rate = 0.15, random_state = 0, max_depth = 8, reg_lambda = 0.5)
xgb.fit(X_train, y_train, early_stopping_rounds = 200, eval_set = [(X_test,y_test)], eval_metric = 'rmse', verbose = True)
cv_pred = xgb.predict(X_test)
print(np.sqrt(mean_squared_error(y_test, cv_pred)))
print(xgb.score(X_test,y_test))
# Out:
# [0]	validation_0-rmse:1273.52295
# [1]	validation_0-rmse:1087.38135
# [2]	validation_0-rmse:930.45941
# [3]	validation_0-rmse:796.65918
# [4]	validation_0-rmse:682.32288
# [5]	validation_0-rmse:584.81995
# [6]	validation_0-rmse:501.59265
# [7]	validation_0-rmse:432.01517
# [8]	validation_0-rmse:372.01889
# [9]	validation_0-rmse:320.78885
# [10]	validation_0-rmse:278.30759
# [11]	validation_0-rmse:241.59967
# [12]	validation_0-rmse:209.12605
# [13]	validation_0-rmse:182.61716
# [14]	validation_0-rmse:159.29717
# [15]	validation_0-rmse:139.58347
# [16]	validation_0-rmse:122.90035
# [17]	validation_0-rmse:109.28382
# [18]	validation_0-rmse:97.19595
# [19]	validation_0-rmse:86.97683
# [20]	validation_0-rmse:78.30250
# [21]	validation_0-rmse:71.14925
# [22]	validation_0-rmse:65.64549
# [23]	validation_0-rmse:61.31678
# [24]	validation_0-rmse:57.49553
# [25]	validation_0-rmse:53.98745
# [26]	validation_0-rmse:50.93724
# [27]	validation_0-rmse:49.07356
# [28]	validation_0-rmse:47.57561
# [29]	validation_0-rmse:46.32195
# [30]	validation_0-rmse:45.28944
# [31]	validation_0-rmse:44.49365
# [32]	validation_0-rmse:43.38282
# [33]	validation_0-rmse:42.43176
# [34]	validation_0-rmse:41.62167
# [35]	validation_0-rmse:40.92491
# [36]	validation_0-rmse:40.31465
# [37]	validation_0-rmse:39.79147
# [38]	validation_0-rmse:39.30699
# [39]	validation_0-rmse:38.92310
# [40]	validation_0-rmse:38.76180
# [41]	validation_0-rmse:38.53913
# [42]	validation_0-rmse:38.39024
# [43]	validation_0-rmse:38.28105
# [44]	validation_0-rmse:38.20537
# [45]	validation_0-rmse:38.12760
# [46]	validation_0-rmse:38.07436
# [47]	validation_0-rmse:37.89822
# [48]	validation_0-rmse:37.88562
# [49]	validation_0-rmse:37.84935
# [50]	validation_0-rmse:37.78258
# [51]	validation_0-rmse:37.77135
# [52]	validation_0-rmse:37.76227
# [53]	validation_0-rmse:37.66553
# [54]	validation_0-rmse:37.64011
# [55]	validation_0-rmse:37.64395
# [56]	validation_0-rmse:37.62122
# [57]	validation_0-rmse:37.65215
# [58]	validation_0-rmse:37.64847
# [59]	validation_0-rmse:37.63948
# [60]	validation_0-rmse:37.55772
# [61]	validation_0-rmse:37.48860
# [62]	validation_0-rmse:37.45106
# [63]	validation_0-rmse:37.47239
# [64]	validation_0-rmse:37.47477
# [65]	validation_0-rmse:37.48166
# [66]	validation_0-rmse:37.50404
# [67]	validation_0-rmse:37.50386
# [68]	validation_0-rmse:37.50283
# [69]	validation_0-rmse:37.47954
# [70]	validation_0-rmse:37.48778
# [71]	validation_0-rmse:37.48268
# [72]	validation_0-rmse:37.48015
# [73]	validation_0-rmse:37.49363
# [74]	validation_0-rmse:37.49130
# [75]	validation_0-rmse:37.48146
# [76]	validation_0-rmse:37.47726
# [77]	validation_0-rmse:37.47016
# [78]	validation_0-rmse:37.47204
# [79]	validation_0-rmse:37.47571
# [80]	validation_0-rmse:37.49215
# [81]	validation_0-rmse:37.49746
# [82]	validation_0-rmse:37.48654
# [83]	validation_0-rmse:37.48211
# [84]	validation_0-rmse:37.48262
# [85]	validation_0-rmse:37.48325
# [86]	validation_0-rmse:37.49966
# [87]	validation_0-rmse:37.49955
# [88]	validation_0-rmse:37.51173
# [89]	validation_0-rmse:37.50975
# [90]	validation_0-rmse:37.50655
# [91]	validation_0-rmse:37.50884
# [92]	validation_0-rmse:37.50919
# [93]	validation_0-rmse:37.51111
# [94]	validation_0-rmse:37.50312
# [95]	validation_0-rmse:37.50501
# [96]	validation_0-rmse:37.50762
# [97]	validation_0-rmse:37.48523
# [98]	validation_0-rmse:37.49871
# [99]	validation_0-rmse:37.50205
# [100]	validation_0-rmse:37.50279
# [101]	validation_0-rmse:37.50339
# [102]	validation_0-rmse:37.51126
# [103]	validation_0-rmse:37.50513
# [104]	validation_0-rmse:37.48424
# [105]	validation_0-rmse:37.47886
# [106]	validation_0-rmse:37.47829
# [107]	validation_0-rmse:37.48378
# [108]	validation_0-rmse:37.48587
# [109]	validation_0-rmse:37.48521
# [110]	validation_0-rmse:37.48440
# [111]	validation_0-rmse:37.48091
# [112]	validation_0-rmse:37.48223
# [113]	validation_0-rmse:37.47809
# [114]	validation_0-rmse:37.48127
# [115]	validation_0-rmse:37.47954
# [116]	validation_0-rmse:37.47930
# [117]	validation_0-rmse:37.47706
# [118]	validation_0-rmse:37.49696
# [119]	validation_0-rmse:37.49656
# [120]	validation_0-rmse:37.51247
# [121]	validation_0-rmse:37.50995
# [122]	validation_0-rmse:37.50939
# [123]	validation_0-rmse:37.50872
# [124]	validation_0-rmse:37.50752
# [125]	validation_0-rmse:37.50805
# [126]	validation_0-rmse:37.50697
# [127]	validation_0-rmse:37.50909
# [128]	validation_0-rmse:37.51430
# [129]	validation_0-rmse:37.51476
# [130]	validation_0-rmse:37.51533
# [131]	validation_0-rmse:37.51569
# [132]	validation_0-rmse:37.51660
# [133]	validation_0-rmse:37.51322
# [134]	validation_0-rmse:37.51350
# [135]	validation_0-rmse:37.51415
# [136]	validation_0-rmse:37.52405
# [137]	validation_0-rmse:37.51366
# [138]	validation_0-rmse:37.51720
# [139]	validation_0-rmse:37.52755
# [140]	validation_0-rmse:37.52885
# [141]	validation_0-rmse:37.52820
# [142]	validation_0-rmse:37.52750
# [143]	validation_0-rmse:37.52724
# [144]	validation_0-rmse:37.52789
# [145]	validation_0-rmse:37.52795
# [146]	validation_0-rmse:37.52845
# [147]	validation_0-rmse:37.52251
# [148]	validation_0-rmse:37.52151
# [149]	validation_0-rmse:37.51960
# [150]	validation_0-rmse:37.51751
# [151]	validation_0-rmse:37.51982
# [152]	validation_0-rmse:37.52944
# [153]	validation_0-rmse:37.53396
# [154]	validation_0-rmse:37.53369
# [155]	validation_0-rmse:37.53971
# [156]	validation_0-rmse:37.54042
# [157]	validation_0-rmse:37.53111
# [158]	validation_0-rmse:37.52889
# [159]	validation_0-rmse:37.53225
# [160]	validation_0-rmse:37.53072
# [161]	validation_0-rmse:37.52970
# [162]	validation_0-rmse:37.52942
# [163]	validation_0-rmse:37.52611
# [164]	validation_0-rmse:37.52625
# [165]	validation_0-rmse:37.52516
# [166]	validation_0-rmse:37.52022
# [167]	validation_0-rmse:37.52186
# [168]	validation_0-rmse:37.52027
# [169]	validation_0-rmse:37.52091
# [170]	validation_0-rmse:37.51953
# [171]	validation_0-rmse:37.51989
# [172]	validation_0-rmse:37.52073
# [173]	validation_0-rmse:37.51865
# [174]	validation_0-rmse:37.51845
# [175]	validation_0-rmse:37.51941
# [176]	validation_0-rmse:37.51849
# [177]	validation_0-rmse:37.51946
# [178]	validation_0-rmse:37.51548
# [179]	validation_0-rmse:37.51217
# [180]	validation_0-rmse:37.51257
# [181]	validation_0-rmse:37.50979
# [182]	validation_0-rmse:37.50966
# [183]	validation_0-rmse:37.51271
# [184]	validation_0-rmse:37.51092
# [185]	validation_0-rmse:37.50844
# [186]	validation_0-rmse:37.50738
# [187]	validation_0-rmse:37.50528
# [188]	validation_0-rmse:37.50928
# [189]	validation_0-rmse:37.50981
# [190]	validation_0-rmse:37.51330
# [191]	validation_0-rmse:37.50872
# [192]	validation_0-rmse:37.50794
# [193]	validation_0-rmse:37.51160
# [194]	validation_0-rmse:37.51191
# [195]	validation_0-rmse:37.51201
# [196]	validation_0-rmse:37.51226
# [197]	validation_0-rmse:37.51147
# [198]	validation_0-rmse:37.51285
# [199]	validation_0-rmse:37.51322
# [200]	validation_0-rmse:37.51322
# [201]	validation_0-rmse:37.51015
# [202]	validation_0-rmse:37.51068
# [203]	validation_0-rmse:37.50699
# [204]	validation_0-rmse:37.50737
# [205]	validation_0-rmse:37.50701
# [206]	validation_0-rmse:37.50842
# [207]	validation_0-rmse:37.50716
# [208]	validation_0-rmse:37.50678
# [209]	validation_0-rmse:37.50355
# [210]	validation_0-rmse:37.50299
# [211]	validation_0-rmse:37.50580
# [212]	validation_0-rmse:37.50700
# [213]	validation_0-rmse:37.50753
# [214]	validation_0-rmse:37.50875
# [215]	validation_0-rmse:37.50928
# [216]	validation_0-rmse:37.51116
# [217]	validation_0-rmse:37.51447
# [218]	validation_0-rmse:37.51402
# [219]	validation_0-rmse:37.50904
# [220]	validation_0-rmse:37.50923
# [221]	validation_0-rmse:37.51177
# [222]	validation_0-rmse:37.50869
# [223]	validation_0-rmse:37.50895
# [224]	validation_0-rmse:37.50689
# [225]	validation_0-rmse:37.50828
# [226]	validation_0-rmse:37.50647
# [227]	validation_0-rmse:37.50959
# [228]	validation_0-rmse:37.51250
# [229]	validation_0-rmse:37.51696
# [230]	validation_0-rmse:37.51817
# [231]	validation_0-rmse:37.52485
# [232]	validation_0-rmse:37.52512
# [233]	validation_0-rmse:37.52431
# [234]	validation_0-rmse:37.52479
# [235]	validation_0-rmse:37.52626
# [236]	validation_0-rmse:37.52680
# [237]	validation_0-rmse:37.52760
# [238]	validation_0-rmse:37.52941
# [239]	validation_0-rmse:37.53191
# [240]	validation_0-rmse:37.53319
# [241]	validation_0-rmse:37.53381
# [242]	validation_0-rmse:37.53513
# [243]	validation_0-rmse:37.54155
# [244]	validation_0-rmse:37.54658
# [245]	validation_0-rmse:37.54523
# [246]	validation_0-rmse:37.54437
# [247]	validation_0-rmse:37.54463
# [248]	validation_0-rmse:37.54351
# [249]	validation_0-rmse:37.53962
# [250]	validation_0-rmse:37.53990
# [251]	validation_0-rmse:37.53995
# [252]	validation_0-rmse:37.54447
# [253]	validation_0-rmse:37.54515
# [254]	validation_0-rmse:37.54465
# [255]	validation_0-rmse:37.54573
# [256]	validation_0-rmse:37.54223
# [257]	validation_0-rmse:37.54274
# [258]	validation_0-rmse:37.54601
# [259]	validation_0-rmse:37.54281
# [260]	validation_0-rmse:37.54295
# [261]	validation_0-rmse:37.54171
# 37.45106593390355
# 0.9745127843876763

# %%
y_predict=LinearRegression_model.predict(X_test)
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from math import sqrt

k=X_test.shape[1]
n=len(X_test)
RMSE= float(format(np.sqrt(mean_squared_error(y_test,y_predict)),'.3f'))
MSE= mean_squared_error(y_test,y_predict)
MAE= mean_absolute_error(y_test,y_predict)
r2=r2_score(y_test,y_predict)
adj_r2= 1-(1-r2)*(n-1)/(n-k-1)

print("RMSE= ",RMSE)
print("MSE= ",MSE)
print("MAE= ",MAE)
print("R2= ",r2)
print("Adjusted R2= ",adj_r2)
# Out:
# RMSE=  11.694
# MSE=  136.73950853908804
# MAE=  8.007098606860524
# R2=  0.9975152194359665
# Adjusted R2=  0.997501770014781

# %%
b=y_test.to_frame()
a = pd.DataFrame(y_predict,columns=["Predicted value"],index=b.index)
result = pd.concat([b, a], axis=1)
result
# Out:
#                     Low  Predicted value
# 2018-01-05  1320.300049      1311.934049
# 2018-01-08  1314.599976      1311.523589
# 2018-01-09  1309.599976      1301.338916
# 2018-01-10  1315.300049      1311.979164
# 2018-01-11  1316.300049      1308.726077
# ...                 ...              ...
# 2020-12-23  1864.500000      1854.461881
# 2020-12-28  1873.699951      1882.791643
# 2020-12-29  1879.699951      1868.719973
# 2020-12-30  1877.300049      1867.384948
# 2020-12-31  1892.699951      1884.201244
#
# [744 rows x 2 columns]

# %%
# plotting
plt.figure(figsize=(16,10))
plt.plot(a, label="Predicted Close Price")
plt.plot(b, label="Testing Close Price")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), fancybox=True, shadow=True, ncol=2)
plt.show()
